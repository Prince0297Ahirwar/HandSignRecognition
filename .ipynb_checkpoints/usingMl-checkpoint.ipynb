# %%
# !conda info
# Out:
#      active environment : py37gpu
#     active env location : C:\Users\91963\anaconda3\envs\py37gpu
#             shell level : 1
#        user config file : C:\Users\91963\.condarc
#  populated config files : C:\Users\91963\.condarc
#           conda version : 4.10.1
#     conda-build version : 3.21.4
#          python version : 3.8.8.final.0
#        virtual packages : __cuda=11.5=0
#                           __win=0=0
#                           __archspec=1=x86_64
#        base environment : C:\Users\91963\anaconda3  (writable)
#       conda av data dir : C:\Users\91963\anaconda3\etc\conda
#   conda av metadata url : https://repo.anaconda.com/pkgs/main
#            channel URLs : https://repo.anaconda.com/pkgs/main/win-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/win-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#                           https://repo.anaconda.com/pkgs/msys2/win-64
#                           https://repo.anaconda.com/pkgs/msys2/noarch
#           package cache : C:\Users\91963\anaconda3\pkgs
#                           C:\Users\91963\.conda\pkgs
#                           C:\Users\91963\AppData\Local\conda\conda\pkgs
#        envs directories : C:\Users\91963\anaconda3\envs
#                           C:\Users\91963\.conda\envs
#                           C:\Users\91963\AppData\Local\conda\conda\envs
#                platform : win-64
#              user-agent : conda/4.10.1 requests/2.25.1 CPython/3.8.8 Windows/10 Windows/10.0.19041
#           administrator : False
#              netrc file : None
#            offline mode : False

# %%
import cv2 #opencv
import numpy as np
import os   #helps with path
from matplotlib import pyplot as plt #to use plt.imshow()
import time              #to measure time between frames 
import mediapipe as mp

# %%
mpDraw=mp.solutions.drawing_utils
mpHands=mp.solutions.hands

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB because by default opencv use bgr but we need rgb for mediapipe to process image
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    if results.multi_hand_landmarks:
        for handsLms in results.multi_hand_landmarks:
            mpDraw.draw_landmarks(image,handsLms, mpHands.HAND_CONNECTIONS,
                             mpDraw.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mpDraw.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2) )

# %% [markdown]
# # 1.   detecting only  hands using mediapipe

# %%
current = time.time()
cap = cv2.VideoCapture(0) #creating video capture object
## Set mediapipe model
with mpHands.Hands() as holistic:
    while cap.isOpened():
        #reading feed current frame
        ret,frame = cap.read() 

        #make detection
        image, results = mediapipe_detection(frame, holistic)
        print(results.multi_handedness)

        # Draw landmarks
        draw_landmarks(image, results)
        
        present = time.time()
        
        if (present - current) > 1000000:
            break

        #showing to screen
        cv2.imshow("Open Cv",image) 
        if cv2.waitKey(10) & 0xFF == ord('q'): #wait for 34 milli second to check if q is pressed on keyboard
            break 
    cap.release() #release our webcame
    cv2.destroyAllWindows()#destroy all windows opened till now
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# [classification {
#   index: 0
#   score: 0.9534661173820496
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9494732618331909
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9611424207687378
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9401428699493408
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9626241326332092
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9386242032051086
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9661754965782166
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9520741105079651
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9620318412780762
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9380072355270386
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9591655135154724
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9252498149871826
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9374665021896362
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9155373573303223
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9458742737770081
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9432464241981506
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9503176212310791
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9083518981933594
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9291632771492004
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9156162142753601
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.934827983379364
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.916791558265686
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9573200345039368
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9442667961120605
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.937213659286499
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9378687739372253
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9655437469482422
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9036006927490234
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9737060070037842
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9223825335502625
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9600925445556641
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9050873517990112
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9567610025405884
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9071924686431885
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9709726572036743
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.94003826379776
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9682745933532715
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9102068543434143
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9709640145301819
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9167174100875854
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.966422975063324
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9304701685905457
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9486454129219055
#   label: "Left"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9255313277244568
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.