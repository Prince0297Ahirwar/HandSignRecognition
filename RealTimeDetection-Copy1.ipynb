# %% [markdown]
# # 1. Import and Install Dependencies

# %%
# !conda info
# Out:
#      active environment : py37gpu
#     active env location : C:\Users\91963\anaconda3\envs\py37gpu
#             shell level : 1
#        user config file : C:\Users\91963\.condarc
#  populated config files : C:\Users\91963\.condarc
#           conda version : 4.10.1
#     conda-build version : 3.21.4
#          python version : 3.8.8.final.0
#        virtual packages : __cuda=11.5=0
#                           __win=0=0
#                           __archspec=1=x86_64
#        base environment : C:\Users\91963\anaconda3  (writable)
#       conda av data dir : C:\Users\91963\anaconda3\etc\conda
#   conda av metadata url : https://repo.anaconda.com/pkgs/main
#            channel URLs : https://repo.anaconda.com/pkgs/main/win-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/win-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#                           https://repo.anaconda.com/pkgs/msys2/win-64
#                           https://repo.anaconda.com/pkgs/msys2/noarch
#           package cache : C:\Users\91963\anaconda3\pkgs
#                           C:\Users\91963\.conda\pkgs
#                           C:\Users\91963\AppData\Local\conda\conda\pkgs
#        envs directories : C:\Users\91963\anaconda3\envs
#                           C:\Users\91963\.conda\envs
#                           C:\Users\91963\AppData\Local\conda\conda\envs
#                platform : win-64
#              user-agent : conda/4.10.1 requests/2.25.1 CPython/3.8.8 Windows/10 Windows/10.0.19041
#           administrator : False
#              netrc file : None
#            offline mode : False

# %%
# !pip install opencv-python mediapipe sklearn matplotlib

# %%
import cv2 #opencv
import numpy as np
import os   #helps with path
from matplotlib import pyplot as plt #to use plt.imshow()
import time              #to measure time between frames 
import mediapipe as mp

# %% [markdown]
# # 2. Extracting Keypoints using media pipe Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB because by default opencv use bgr but we need rgb for mediapipe to process image
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
#  cv2.cvtColor??

# %%
def draw_landmarks(image, results):
#     mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
#     mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
# mp_drawing.draw_landmarks??

# %%
# mp_holistic.POSE_CONNECTIONS

# %% [markdown]
# # function to draw styled landmarks same as drawlandmarks but with different style applied to landmarks

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
#     mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
#                              mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
#                              mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
#                              ) 
#     mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
#                              mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
#                              mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
#                              ) 
#     # Draw pose connections
#     mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
#                              mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
#                              mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
#                              ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0) #creating video capture object
## Set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        #reading feed current frame
        ret,frame = cap.read() 

        #make detection
        image, results = mediapipe_detection(frame, holistic)
        print(results)

        # Draw landmarks
        draw_styled_landmarks(image, results)

        #showing to screen
        cv2.imshow("Open Cv",image) 
        if cv2.waitKey(10) & 0xFF == ord('q'): #wait for 34 milli second to check if q is pressed on keyboard
            break 
    cap.release() #release our webcame
    cv2.destroyAllWindows()#destroy all windows opened till now
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %% [markdown]
# # Extract key points

# %%
# len(results.left_hand_landmarks.landmark),len(results.pose_landmarks.landmark),len(results.face_landmarks.landmark)

# %%
# len(results.left_hand_landmarks.landmark),len(results.pose_landmarks.landmark),len(results.face_landmarks.landmark)

# %%
# pose = []
# for res in results.pose_landmarks.landmark:
#     test = np.array([res.x, res.y, res.z, res.visibility])
#     pose.append(test)

# %%
# print("hello") if False else print("good")
468*3,33*4,21*3
# Out:
# (1404, 132, 63)

# %%
# results.left_hand_landmarks.landmark[0],(results.pose_landmarks.landmark[0]),(results.face_landmarks.landmark[0])

# %%
# pose = np.array([[res.x,res.y,res.z] for res in results.left_hand_landmarks.landmark ])

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-c23279c7a4c6> in <module>
# ----> 1 pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
#       2 face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
#       3 lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
#       4 rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
#
# NameError: name 'results' is not defined

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
test = extract_keypoints(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a8a7178d1bbc> in <module>
# ----> 1 test = extract_keypoints(results)
#
# NameError: name 'results' is not defined

# %%
np.save('0',test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-0f5a3edab94f> in <module>
# ----> 1 np.save('0',test)
#
# NameError: name 'test' is not defined

# %%
np.load('0.npy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-e335b5dd3f0e> in <module>
# ----> 1 np.load('0.npy')
#
# ~\anaconda3\envs\py37gpu\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# FileNotFoundError: [Errno 2] No such file or directory: '0.npy'

# %% [markdown]
# # 4. Setup folder for collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['a', 'b', 'c','d','e','f','g','h','i','j','  '])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 30

# %%
# run this only once because folder are created permanentley
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. collect keypoint for training and testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)
#                 print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess data create labels and features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'thanks': 1, 'iloveyou': 2}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (90, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (90,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (90, 30, 1662)

# %%
y = to_categorical(labels).astype(int) #one hot encoding to convert categorial variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (5, 3)

# %% [markdown]
# # 7  Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs2')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()

# %%
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
model.add(LSTM(128, return_sequences=True, activation='relu'))
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
model.add(LSTM(64, return_sequences=False, activation='relu'))
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
model.add(Dense(64, activation='relu'))

# %%
model.add(Dense(32, activation='relu'))

# %%
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
res = [.7, 0.2, 0.1]

# %%
actions[np.argmax(res)]
# Out:
# 'hello'

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=200, callbacks=[tb_callback])
# Out:
# Epoch 1/200
# 2/3 [===================>..........] - ETA: 1s - loss: 1.1771 - categorical_accuracy: 0.3594WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.6089s vs `on_train_batch_end` time: 1.4591s). Check your callbacks.
# 3/3 [==============================] - 3s 890ms/step - loss: 2.0172 - categorical_accuracy: 0.3294
# Epoch 2/200
# 3/3 [==============================] - 1s 287ms/step - loss: 5.6176 - categorical_accuracy: 0.5059
# Epoch 3/200
# 3/3 [==============================] - 1s 280ms/step - loss: 3.8031 - categorical_accuracy: 0.3176
# Epoch 4/200
# 3/3 [==============================] - 1s 313ms/step - loss: 1.4509 - categorical_accuracy: 0.3176
# Epoch 5/200
# 3/3 [==============================] - 1s 317ms/step - loss: 1.8648 - categorical_accuracy: 0.3765
# Epoch 6/200
# 3/3 [==============================] - 1s 340ms/step - loss: 1.2014 - categorical_accuracy: 0.3412
# Epoch 7/200
# 3/3 [==============================] - 1s 278ms/step - loss: 1.3876 - categorical_accuracy: 0.3059
# Epoch 8/200
# 3/3 [==============================] - 1s 265ms/step - loss: 1.4540 - categorical_accuracy: 0.2824
# Epoch 9/200
# 3/3 [==============================] - 1s 200ms/step - loss: 1.1828 - categorical_accuracy: 0.3176
# Epoch 10/200
# 3/3 [==============================] - 1s 226ms/step - loss: 1.3991 - categorical_accuracy: 0.2588
# Epoch 11/200
# 3/3 [==============================] - 1s 195ms/step - loss: 1.1721 - categorical_accuracy: 0.3529
# Epoch 12/200
# 3/3 [==============================] - 1s 201ms/step - loss: 1.5458 - categorical_accuracy: 0.3412
# Epoch 13/200
# 3/3 [==============================] - 1s 310ms/step - loss: 1.5011 - categorical_accuracy: 0.3059
# Epoch 14/200
# 3/3 [==============================] - 1s 271ms/step - loss: 1.8237 - categorical_accuracy: 0.3412
# Epoch 15/200
# 3/3 [==============================] - 1s 277ms/step - loss: 1.0773 - categorical_accuracy: 0.3529
# Epoch 16/200
# 3/3 [==============================] - 1s 320ms/step - loss: 1.1301 - categorical_accuracy: 0.3529
# Epoch 17/200
# 3/3 [==============================] - 1s 282ms/step - loss: 1.0961 - categorical_accuracy: 0.3765
# Epoch 18/200
# 3/3 [==============================] - 1s 286ms/step - loss: 1.1000 - categorical_accuracy: 0.3529
# Epoch 19/200
# 3/3 [==============================] - 1s 309ms/step - loss: 1.0959 - categorical_accuracy: 0.3529
# Epoch 20/200
# 3/3 [==============================] - 1s 296ms/step - loss: 1.0869 - categorical_accuracy: 0.3529
# Epoch 21/200
# 3/3 [==============================] - 1s 279ms/step - loss: 1.0770 - categorical_accuracy: 0.3765
# Epoch 22/200
# 3/3 [==============================] - 1s 281ms/step - loss: 1.0675 - categorical_accuracy: 0.4941
# Epoch 23/200
# 3/3 [==============================] - 1s 277ms/step - loss: 1.0577 - categorical_accuracy: 0.6235
# Epoch 24/200
# 3/3 [==============================] - 1s 282ms/step - loss: 1.0353 - categorical_accuracy: 0.4941
# Epoch 25/200
# 3/3 [==============================] - 1s 305ms/step - loss: 0.9972 - categorical_accuracy: 0.4706
# Epoch 26/200
# 3/3 [==============================] - 1s 210ms/step - loss: 0.9289 - categorical_accuracy: 0.6235
# Epoch 27/200
# 3/3 [==============================] - 1s 289ms/step - loss: 0.9012 - categorical_accuracy: 0.5529
# Epoch 28/200
# 3/3 [==============================] - 1s 293ms/step - loss: 1.0739 - categorical_accuracy: 0.4941
# Epoch 29/200
# 3/3 [==============================] - 1s 295ms/step - loss: 1.1533 - categorical_accuracy: 0.3294
# Epoch 30/200
# 3/3 [==============================] - 1s 311ms/step - loss: 1.0911 - categorical_accuracy: 0.3176
# Epoch 31/200
# 3/3 [==============================] - 1s 284ms/step - loss: 1.0444 - categorical_accuracy: 0.4471
# Epoch 32/200
# 3/3 [==============================] - 1s 291ms/step - loss: 1.1634 - categorical_accuracy: 0.3529
# Epoch 33/200
# 3/3 [==============================] - 1s 281ms/step - loss: 1.0461 - categorical_accuracy: 0.4235
# Epoch 34/200
# 3/3 [==============================] - 1s 285ms/step - loss: 1.0416 - categorical_accuracy: 0.2941
# Epoch 35/200
# 3/3 [==============================] - 1s 296ms/step - loss: 0.9688 - categorical_accuracy: 0.6471
# Epoch 36/200
# 3/3 [==============================] - 1s 322ms/step - loss: 0.9142 - categorical_accuracy: 0.6471
# Epoch 37/200
# 3/3 [==============================] - 1s 278ms/step - loss: 0.8144 - categorical_accuracy: 0.6235
# Epoch 38/200
# 3/3 [==============================] - 1s 295ms/step - loss: 0.7016 - categorical_accuracy: 0.6118
# Epoch 39/200
# 3/3 [==============================] - 1s 282ms/step - loss: 0.6646 - categorical_accuracy: 0.5765
# Epoch 40/200
# 3/3 [==============================] - 1s 335ms/step - loss: 0.6358 - categorical_accuracy: 0.6941
# Epoch 41/200
# 3/3 [==============================] - 1s 344ms/step - loss: 0.5752 - categorical_accuracy: 0.6588
# Epoch 42/200
# 3/3 [==============================] - 1s 314ms/step - loss: 0.5506 - categorical_accuracy: 0.6000
# Epoch 43/200
# 3/3 [==============================] - 1s 281ms/step - loss: 0.5591 - categorical_accuracy: 0.6941
# Epoch 44/200
# 3/3 [==============================] - 1s 282ms/step - loss: 0.5357 - categorical_accuracy: 0.6706
# Epoch 45/200
# 3/3 [==============================] - 1s 275ms/step - loss: 0.6283 - categorical_accuracy: 0.6118
# Epoch 46/200
# 3/3 [==============================] - 1s 274ms/step - loss: 0.7075 - categorical_accuracy: 0.5765
# Epoch 47/200
# 3/3 [==============================] - 1s 283ms/step - loss: 0.5866 - categorical_accuracy: 0.6471
# Epoch 48/200
# 3/3 [==============================] - 1s 300ms/step - loss: 0.5441 - categorical_accuracy: 0.7059
# Epoch 49/200
# 3/3 [==============================] - 1s 290ms/step - loss: 0.5422 - categorical_accuracy: 0.6824
# Epoch 50/200
# 3/3 [==============================] - 1s 275ms/step - loss: 0.5378 - categorical_accuracy: 0.6706
# Epoch 51/200
# 3/3 [==============================] - 1s 286ms/step - loss: 0.5200 - categorical_accuracy: 0.6941
# Epoch 52/200
# 3/3 [==============================] - 1s 288ms/step - loss: 0.5155 - categorical_accuracy: 0.6941
# Epoch 53/200
# 3/3 [==============================] - 1s 269ms/step - loss: 0.4962 - categorical_accuracy: 0.7529
# Epoch 54/200
# 3/3 [==============================] - 1s 275ms/step - loss: 0.5466 - categorical_accuracy: 0.7412
# Epoch 55/200
# 3/3 [==============================] - 1s 283ms/step - loss: 0.7591 - categorical_accuracy: 0.6471
# Epoch 56/200
# 3/3 [==============================] - 1s 271ms/step - loss: 1.4775 - categorical_accuracy: 0.3647
# Epoch 57/200
# 3/3 [==============================] - 1s 280ms/step - loss: 0.7473 - categorical_accuracy: 0.5412
# Epoch 58/200
# 3/3 [==============================] - 1s 317ms/step - loss: 0.6023 - categorical_accuracy: 0.6588
# Epoch 59/200
# 3/3 [==============================] - 1s 285ms/step - loss: 0.7638 - categorical_accuracy: 0.6588
# Epoch 60/200
# 3/3 [==============================] - 1s 273ms/step - loss: 0.5825 - categorical_accuracy: 0.6941
# Epoch 61/200
# 3/3 [==============================] - 1s 278ms/step - loss: 0.5867 - categorical_accuracy: 0.6588
# Epoch 62/200
# 3/3 [==============================] - 1s 213ms/step - loss: 0.5237 - categorical_accuracy: 0.6706
# Epoch 63/200
# 3/3 [==============================] - 1s 280ms/step - loss: 0.5286 - categorical_accuracy: 0.7294
# Epoch 64/200
# 3/3 [==============================] - 1s 276ms/step - loss: 0.5220 - categorical_accuracy: 0.6941
# Epoch 65/200
# 3/3 [==============================] - 1s 288ms/step - loss: 0.5157 - categorical_accuracy: 0.6353
# Epoch 66/200
# 3/3 [==============================] - 1s 300ms/step - loss: 0.5189 - categorical_accuracy: 0.6588
# Epoch 67/200
# 3/3 [==============================] - 1s 300ms/step - loss: 0.5010 - categorical_accuracy: 0.7059
# Epoch 68/200
# 3/3 [==============================] - 1s 313ms/step - loss: 0.4912 - categorical_accuracy: 0.6706
# Epoch 69/200
# 3/3 [==============================] - 1s 298ms/step - loss: 0.5386 - categorical_accuracy: 0.6000
# Epoch 70/200
# 3/3 [==============================] - 1s 267ms/step - loss: 0.4971 - categorical_accuracy: 0.7059
# Epoch 71/200
# 3/3 [==============================] - 1s 274ms/step - loss: 0.4837 - categorical_accuracy: 0.6824
# Epoch 72/200
# 3/3 [==============================] - 1s 240ms/step - loss: 0.4852 - categorical_accuracy: 0.6941
# Epoch 73/200
# 3/3 [==============================] - 1s 235ms/step - loss: 0.4832 - categorical_accuracy: 0.7647
# Epoch 74/200
# 3/3 [==============================] - 1s 207ms/step - loss: 0.4675 - categorical_accuracy: 0.6941
# Epoch 75/200
# 3/3 [==============================] - 1s 281ms/step - loss: 0.5080 - categorical_accuracy: 0.6588
# Epoch 76/200
# 3/3 [==============================] - 1s 295ms/step - loss: 0.4986 - categorical_accuracy: 0.6706
# Epoch 77/200
# 3/3 [==============================] - 1s 275ms/step - loss: 0.4800 - categorical_accuracy: 0.7176
# Epoch 78/200
# 3/3 [==============================] - 1s 266ms/step - loss: 0.4700 - categorical_accuracy: 0.7176
# Epoch 79/200
# 3/3 [==============================] - 1s 237ms/step - loss: 0.4554 - categorical_accuracy: 0.7176
# Epoch 80/200
# 3/3 [==============================] - 1s 309ms/step - loss: 0.4228 - categorical_accuracy: 0.8471
# Epoch 81/200
# 3/3 [==============================] - 1s 283ms/step - loss: 0.3962 - categorical_accuracy: 0.8353
# Epoch 82/200
# 3/3 [==============================] - 1s 275ms/step - loss: 0.4380 - categorical_accuracy: 0.8118
# Epoch 83/200
# 3/3 [==============================] - 1s 289ms/step - loss: 0.4608 - categorical_accuracy: 0.7294
# Epoch 84/200
# 3/3 [==============================] - 1s 237ms/step - loss: 0.4524 - categorical_accuracy: 0.8471
# Epoch 85/200
# 3/3 [==============================] - 1s 279ms/step - loss: 0.4475 - categorical_accuracy: 0.8353
# Epoch 86/200
# 3/3 [==============================] - 1s 279ms/step - loss: 0.4204 - categorical_accuracy: 0.8000
# Epoch 87/200
# 3/3 [==============================] - 1s 260ms/step - loss: 0.5083 - categorical_accuracy: 0.7882
# Epoch 88/200
# 3/3 [==============================] - 1s 192ms/step - loss: 0.4567 - categorical_accuracy: 0.7765
# Epoch 89/200
# 3/3 [==============================] - 1s 244ms/step - loss: 0.4040 - categorical_accuracy: 0.8000
# Epoch 90/200
# 3/3 [==============================] - 1s 249ms/step - loss: 0.4776 - categorical_accuracy: 0.7412
# Epoch 91/200
# 3/3 [==============================] - 1s 227ms/step - loss: 0.4523 - categorical_accuracy: 0.8118
# Epoch 92/200
# 3/3 [==============================] - 1s 224ms/step - loss: 0.4548 - categorical_accuracy: 0.7882
# Epoch 93/200
# 3/3 [==============================] - 1s 192ms/step - loss: 0.4452 - categorical_accuracy: 0.7765
# Epoch 94/200
# 3/3 [==============================] - 1s 307ms/step - loss: 0.4140 - categorical_accuracy: 0.8000
# Epoch 95/200
# 3/3 [==============================] - 1s 308ms/step - loss: 0.4080 - categorical_accuracy: 0.8000
# Epoch 96/200
# 3/3 [==============================] - 1s 276ms/step - loss: 0.4228 - categorical_accuracy: 0.8235
# Epoch 97/200
# 3/3 [==============================] - 1s 279ms/step - loss: 0.3917 - categorical_accuracy: 0.8000
# Epoch 98/200
# 3/3 [==============================] - 1s 279ms/step - loss: 0.3696 - categorical_accuracy: 0.8353
# Epoch 99/200
# 3/3 [==============================] - 1s 275ms/step - loss: 0.3766 - categorical_accuracy: 0.8118
# Epoch 100/200
# 3/3 [==============================] - 1s 266ms/step - loss: 0.4504 - categorical_accuracy: 0.8000
# Epoch 101/200
# 3/3 [==============================] - 1s 265ms/step - loss: 0.7476 - categorical_accuracy: 0.5412
# Epoch 102/200
# 3/3 [==============================] - 1s 328ms/step - loss: 0.5974 - categorical_accuracy: 0.6588
# Epoch 103/200
# 3/3 [==============================] - 1s 286ms/step - loss: 0.5110 - categorical_accuracy: 0.7529
# Epoch 104/200
# 3/3 [==============================] - 1s 313ms/step - loss: 0.4784 - categorical_accuracy: 0.8000
# Epoch 105/200
# 3/3 [==============================] - 1s 298ms/step - loss: 0.5142 - categorical_accuracy: 0.6824
# Epoch 106/200
# 3/3 [==============================] - 1s 286ms/step - loss: 0.4818 - categorical_accuracy: 0.7647
# Epoch 107/200
# 3/3 [==============================] - 1s 301ms/step - loss: 0.5090 - categorical_accuracy: 0.6824
# Epoch 108/200
# 3/3 [==============================] - 1s 291ms/step - loss: 0.4665 - categorical_accuracy: 0.7176
# Epoch 109/200
# 3/3 [==============================] - 1s 295ms/step - loss: 0.4583 - categorical_accuracy: 0.7882
# Epoch 110/200
# 3/3 [==============================] - 1s 289ms/step - loss: 0.4751 - categorical_accuracy: 0.7294
# Epoch 111/200
# 3/3 [==============================] - 1s 274ms/step - loss: 0.4536 - categorical_accuracy: 0.8000
# Epoch 112/200
# 3/3 [==============================] - 1s 276ms/step - loss: 0.4378 - categorical_accuracy: 0.8235
# Epoch 113/200
# 3/3 [==============================] - 1s 319ms/step - loss: 0.4230 - categorical_accuracy: 0.8353
# Epoch 114/200
# 3/3 [==============================] - 1s 325ms/step - loss: 0.4193 - categorical_accuracy: 0.8235
# Epoch 115/200
# 3/3 [==============================] - 1s 317ms/step - loss: 0.4026 - categorical_accuracy: 0.8118
# Epoch 116/200
# 3/3 [==============================] - 1s 338ms/step - loss: 0.3995 - categorical_accuracy: 0.8000
# Epoch 117/200
# 3/3 [==============================] - 1s 313ms/step - loss: 0.3821 - categorical_accuracy: 0.8235
# Epoch 118/200
# 3/3 [==============================] - 1s 281ms/step - loss: 0.6101 - categorical_accuracy: 0.7176
# Epoch 119/200
# 3/3 [==============================] - 1s 278ms/step - loss: 0.5217 - categorical_accuracy: 0.6706
# Epoch 120/200
# 3/3 [==============================] - 1s 275ms/step - loss: 0.5177 - categorical_accuracy: 0.6706
# Epoch 121/200
# 3/3 [==============================] - 1s 289ms/step - loss: 0.4902 - categorical_accuracy: 0.7059
# Epoch 122/200
# 3/3 [==============================] - 1s 283ms/step - loss: 0.4943 - categorical_accuracy: 0.6706
# Epoch 123/200
# 3/3 [==============================] - 1s 283ms/step - loss: 0.5087 - categorical_accuracy: 0.6824
# Epoch 124/200
# 3/3 [==============================] - 1s 286ms/step - loss: 0.4893 - categorical_accuracy: 0.6941
# Epoch 125/200
# 3/3 [==============================] - 1s 287ms/step - loss: 0.4995 - categorical_accuracy: 0.6941
# Epoch 126/200
# 3/3 [==============================] - 1s 285ms/step - loss: 0.4838 - categorical_accuracy: 0.7412
# Epoch 127/200
# 3/3 [==============================] - 1s 272ms/step - loss: 0.4663 - categorical_accuracy: 0.8000
# Epoch 128/200
# 3/3 [==============================] - 1s 290ms/step - loss: 0.4698 - categorical_accuracy: 0.7176
# Epoch 129/200
# 3/3 [==============================] - 1s 293ms/step - loss: 0.4497 - categorical_accuracy: 0.7765
# Epoch 130/200
# 3/3 [==============================] - 1s 280ms/step - loss: 0.4431 - categorical_accuracy: 0.8000
# Epoch 131/200
# 3/3 [==============================] - 1s 278ms/step - loss: 0.4261 - categorical_accuracy: 0.7882
# Epoch 132/200
# 3/3 [==============================] - 1s 270ms/step - loss: 0.4093 - categorical_accuracy: 0.8235
# Epoch 133/200
# 3/3 [==============================] - 1s 276ms/step - loss: 0.4158 - categorical_accuracy: 0.8235
# Epoch 134/200
# 3/3 [==============================] - 1s 333ms/step - loss: 0.3953 - categorical_accuracy: 0.8235
# Epoch 135/200
# 3/3 [==============================] - 1s 279ms/step - loss: 0.3830 - categorical_accuracy: 0.8353
# Epoch 136/200
# 3/3 [==============================] - 1s 335ms/step - loss: 0.3641 - categorical_accuracy: 0.8353
# Epoch 137/200
# 3/3 [==============================] - 1s 274ms/step - loss: 0.3591 - categorical_accuracy: 0.8471
# Epoch 138/200
# 3/3 [==============================] - 1s 286ms/step - loss: 0.3380 - categorical_accuracy: 0.8706
# Epoch 139/200
# 3/3 [==============================] - 1s 293ms/step - loss: 0.3440 - categorical_accuracy: 0.8824
# Epoch 140/200
# 3/3 [==============================] - 1s 287ms/step - loss: 0.3575 - categorical_accuracy: 0.8471
# Epoch 141/200
# 3/3 [==============================] - 1s 285ms/step - loss: 0.3385 - categorical_accuracy: 0.8588
# Epoch 142/200
# 3/3 [==============================] - 1s 277ms/step - loss: 0.3389 - categorical_accuracy: 0.8353
# Epoch 143/200
# 3/3 [==============================] - 1s 283ms/step - loss: 0.3711 - categorical_accuracy: 0.8471
# Epoch 144/200
# 3/3 [==============================] - 1s 324ms/step - loss: 0.3651 - categorical_accuracy: 0.8471
# Epoch 145/200
# 3/3 [==============================] - 1s 306ms/step - loss: 0.3163 - categorical_accuracy: 0.8588
# Epoch 146/200
# 3/3 [==============================] - 1s 294ms/step - loss: 0.3109 - categorical_accuracy: 0.8824
# Epoch 147/200
# 3/3 [==============================] - 1s 316ms/step - loss: 0.3709 - categorical_accuracy: 0.8353
# Epoch 148/200
# 3/3 [==============================] - 1s 322ms/step - loss: 0.3893 - categorical_accuracy: 0.8118
# Epoch 149/200
# 3/3 [==============================] - 1s 351ms/step - loss: 0.3540 - categorical_accuracy: 0.8353
# Epoch 150/200
# 3/3 [==============================] - 1s 328ms/step - loss: 0.3637 - categorical_accuracy: 0.8353
# Epoch 151/200
# 3/3 [==============================] - 1s 312ms/step - loss: 0.4496 - categorical_accuracy: 0.7529
# Epoch 152/200
# 3/3 [==============================] - 1s 283ms/step - loss: 0.3772 - categorical_accuracy: 0.8235
# Epoch 153/200
# 3/3 [==============================] - 1s 284ms/step - loss: 0.3761 - categorical_accuracy: 0.8353
# Epoch 154/200
# 3/3 [==============================] - 1s 295ms/step - loss: 0.3656 - categorical_accuracy: 0.8353
# Epoch 155/200
# 3/3 [==============================] - 1s 280ms/step - loss: 0.3233 - categorical_accuracy: 0.8588
# Epoch 156/200
# 3/3 [==============================] - 1s 270ms/step - loss: 0.3367 - categorical_accuracy: 0.8706
# Epoch 157/200
# 3/3 [==============================] - 1s 294ms/step - loss: 0.3172 - categorical_accuracy: 0.8588
# Epoch 158/200
# 3/3 [==============================] - 1s 310ms/step - loss: 0.3117 - categorical_accuracy: 0.8706
# Epoch 159/200
# 3/3 [==============================] - 1s 288ms/step - loss: 0.3056 - categorical_accuracy: 0.8824
# Epoch 160/200
# 3/3 [==============================] - 1s 306ms/step - loss: 0.3222 - categorical_accuracy: 0.8706
# Epoch 161/200
# 3/3 [==============================] - 1s 296ms/step - loss: 0.3050 - categorical_accuracy: 0.8471
# Epoch 162/200
# 3/3 [==============================] - 1s 281ms/step - loss: 0.2614 - categorical_accuracy: 0.8941
# Epoch 163/200
# 3/3 [==============================] - 1s 282ms/step - loss: 0.3166 - categorical_accuracy: 0.8941
# Epoch 164/200
# 3/3 [==============================] - 1s 290ms/step - loss: 0.3068 - categorical_accuracy: 0.8588
# Epoch 165/200
# 3/3 [==============================] - 1s 272ms/step - loss: 0.4556 - categorical_accuracy: 0.7882
# Epoch 166/200
# 3/3 [==============================] - 1s 288ms/step - loss: 0.3520 - categorical_accuracy: 0.8706
# Epoch 167/200
# 3/3 [==============================] - 1s 281ms/step - loss: 0.3987 - categorical_accuracy: 0.8353
# Epoch 168/200
# 3/3 [==============================] - 1s 280ms/step - loss: 0.4389 - categorical_accuracy: 0.7647
# Epoch 169/200
# 3/3 [==============================] - 1s 276ms/step - loss: 0.4155 - categorical_accuracy: 0.8118
# Epoch 170/200
# 3/3 [==============================] - 1s 282ms/step - loss: 0.4049 - categorical_accuracy: 0.8000
# Epoch 171/200
# 3/3 [==============================] - 1s 276ms/step - loss: 0.3751 - categorical_accuracy: 0.8471
# Epoch 172/200
# 3/3 [==============================] - 1s 282ms/step - loss: 0.3621 - categorical_accuracy: 0.8235
# Epoch 173/200
# 3/3 [==============================] - 1s 275ms/step - loss: 0.3531 - categorical_accuracy: 0.8353
# Epoch 174/200
# 3/3 [==============================] - 1s 275ms/step - loss: 0.3387 - categorical_accuracy: 0.8588
# Epoch 175/200
# 3/3 [==============================] - 1s 289ms/step - loss: 0.3171 - categorical_accuracy: 0.8471
# Epoch 176/200
# 3/3 [==============================] - 1s 273ms/step - loss: 0.2981 - categorical_accuracy: 0.8706
# Epoch 177/200
# 3/3 [==============================] - 1s 274ms/step - loss: 0.2835 - categorical_accuracy: 0.8706
# Epoch 178/200
# 3/3 [==============================] - 1s 278ms/step - loss: 0.2657 - categorical_accuracy: 0.8824
# Epoch 179/200
# 3/3 [==============================] - 1s 289ms/step - loss: 0.3017 - categorical_accuracy: 0.8706
# Epoch 180/200
# 3/3 [==============================] - 1s 286ms/step - loss: 0.3114 - categorical_accuracy: 0.8941
# Epoch 181/200
# 3/3 [==============================] - 1s 265ms/step - loss: 0.2528 - categorical_accuracy: 0.8941
# Epoch 182/200
# 3/3 [==============================] - 1s 287ms/step - loss: 0.2186 - categorical_accuracy: 0.9294
# Epoch 183/200
# 3/3 [==============================] - 1s 342ms/step - loss: 0.2214 - categorical_accuracy: 0.9412
# Epoch 184/200
# 3/3 [==============================] - 1s 343ms/step - loss: 0.2270 - categorical_accuracy: 0.9059
# Epoch 185/200
# 3/3 [==============================] - 1s 281ms/step - loss: 0.3734 - categorical_accuracy: 0.8353
# Epoch 186/200
# 3/3 [==============================] - 1s 281ms/step - loss: 0.2986 - categorical_accuracy: 0.8824
# Epoch 187/200
# 3/3 [==============================] - 1s 266ms/step - loss: 0.3128 - categorical_accuracy: 0.9176
# Epoch 188/200
# 3/3 [==============================] - 1s 284ms/step - loss: 0.2704 - categorical_accuracy: 0.8824
# Epoch 189/200
# 3/3 [==============================] - 1s 274ms/step - loss: 0.2097 - categorical_accuracy: 0.9294
# Epoch 190/200
# 3/3 [==============================] - 1s 281ms/step - loss: 0.1956 - categorical_accuracy: 0.9412
# Epoch 191/200
# 3/3 [==============================] - 1s 273ms/step - loss: 0.1802 - categorical_accuracy: 0.9294
# Epoch 192/200
# 3/3 [==============================] - 1s 270ms/step - loss: 0.1725 - categorical_accuracy: 0.9294
# Epoch 193/200
# 3/3 [==============================] - 1s 296ms/step - loss: 0.1885 - categorical_accuracy: 0.9176
# Epoch 194/200
# 3/3 [==============================] - 1s 287ms/step - loss: 0.2433 - categorical_accuracy: 0.8706
# Epoch 195/200
# 3/3 [==============================] - 1s 284ms/step - loss: 0.1935 - categorical_accuracy: 0.9294
# Epoch 196/200
# 3/3 [==============================] - 1s 287ms/step - loss: 0.2948 - categorical_accuracy: 0.8941
# Epoch 197/200
# 3/3 [==============================] - 1s 298ms/step - loss: 0.3969 - categorical_accuracy: 0.7882
# Epoch 198/200
# 3/3 [==============================] - 1s 282ms/step - loss: 0.2728 - categorical_accuracy: 0.9059
# Epoch 199/200
# 3/3 [==============================] - 1s 285ms/step - loss: 0.2716 - categorical_accuracy: 0.8824
# Epoch 200/200
# 3/3 [==============================] - 1s 279ms/step - loss: 0.3806 - categorical_accuracy: 0.8353

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 30, 64)            442112
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 30, 128)           98816
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 596,675
# Trainable params: 596,675
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 8.  Make Predictions

# %%
res = model.predict(X_test)

# %%
actions[np.argmax(res[0])]
# Out:
# 'hello'

# %%
actions[np.argmax(y_test[0])]
# Out:
# 'thanks'

# %% [markdown]
# # 9. Save model

# %%
model.save('action.h5')

# %%
del model

# %%
model.load_weights('action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[3, 0],
#         [0, 2]],
#
#        [[3, 0],
#         [0, 2]],
#
#        [[4, 0],
#         [0, 1]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 1.0

# %% [markdown]
# # 11. Test in real time

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
sentence = []
threshold = 0.8

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
        #3. Viz logic
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
